# %% [markdown]
# 1. Add the current date to the text file today.txt as a string.

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 02-06-2023

# %% [markdown]
# 2. Read the text file today.txt into the string today_string

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 02-06-2023

# %% [markdown]
# 3. Parse the date from today_string.

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2023-06-02 00:00:00

# %% [markdown]
# 4. List the files in your current directory

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# .angular-config.json
# .bash_history
# .condarc
# .emulator_console_auth_token
# .gitconfig
# .lesshst
# .node_repl_history
# 18.1.1 data visualization Introduction.ipynb
# AgentLogingReport.csv
# AgentPerformance.csv
# Ashu.txt
# Assignment 1.ipynb
# Assignment12.ipynb
# Assignment13.ipynb
# Assignment14.ipynb
# Assignment15.ipynb
# Assignment16.ipynb
# Assignment17.ipynb
# Assignment18.ipynb
# Assignment19.ipynb
# Assignment20.ipynb
# Assignment21.ipynb
# Attribute DataSet.xlsx
# books.csv
# books.db
# d4ac4633ebd6440fa397b84f1bc94a3c.7z
# Dress Sales.xlsx
# EFCodeFirstExample.BloggingContext.mdf
# EFCodeFirstExample.BloggingContext_log.ldf
# inittk.ini
# inst.ini
# Iterator Iterable.ipynb
# Logging Debuging.ipynb
# NTUSER.DAT
# ntuser.dat.LOG1
# ntuser.dat.LOG2
# NTUSER.DAT{1ef16db1-f2b8-11ea-a2cd-c485a81d765f}.TM.blf
# NTUSER.DAT{1ef16db1-f2b8-11ea-a2cd-c485a81d765f}.TMContainer00000000000000000001.regtrans-ms
# NTUSER.DAT{1ef16db1-f2b8-11ea-a2cd-c485a81d765f}.TMContainer00000000000000000002.regtrans-ms
# ntuser.ini
# ntuser.tmp
# nuuid.ini
# test.json
# test.txt
# Test1.txt
# Test2.txt
# test234.csv
# Text2.txt
# today.txt
# Untitled.ipynb
# Untitled1.ipynb
# Untitled10.ipynb
# Untitled11.ipynb
# Untitled12.ipynb
# Untitled13.ipynb
# Untitled14.ipynb
# Untitled15.ipynb
# Untitled16.ipynb
# Untitled17.ipynb
# Untitled18.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# Untitled6.ipynb
# Untitled7.ipynb
# Untitled8.ipynb
# Untitled9.ipynb
# zoo.py
# anaconda-navigator.ini
# navigator.pid
# content.json
# events.json
# videos.json
# webinars.json
# defaults-2.0.0.ini
# navigator.log
# metadata.json
# navigator_updater.log
# anaconda-navigator-app-err-2.txt
# anaconda-navigator-app-out-2.txt
# anaconda-navigator-app.bat
# adbkey
# adbkey.pub
# analytics.settings
# debug.keystore
# debug.keystore.lock
# firstrun.data
# versions.json
# environments.txt
# update-notifier-npm.json
# config.yaml
# .config
# 5.0.202_IsDockerContainer.dotnetUserLevelCache
# 5.0.202_MachineId.dotnetUserLevelCache
# 5.0.203_IsDockerContainer.dotnetUserLevelCache
# 5.0.203_MachineId.dotnetUserLevelCache
# MachineId.v1.dotnetUserLevelCache
# 20210514094717_51bce722f24d49549310188ea7a3ba6f.trn
# 20210514094717_7e4a853f5cdd428e87194d47d31a435f.trn
# secure_storage
# defaults.properties
# infos.txt
# agents.info
# defaults.info
# https___dl.bintray.com_jetbrains_kotlin_eclipse-plugin_last_compositeArtifacts.xml
# https___dl.bintray.com_jetbrains_kotlin_eclipse-plugin_last_compositeContent.xml
# https___dl.bintray.com_jetbrains_kotlin_eclipse-plugin_last_p2.index
# https___download.eclipse.org_releases_2020-03_202003181000_content.xml.xz
# https___download.eclipse.org_releases_2020-03_202003181000_p2.index
# https___download.eclipse.org_releases_2020-03_compositeArtifacts.jar
# https___download.eclipse.org_releases_2020-03_compositeContent.jar
# https___download.eclipse.org_releases_2020-03_p2.index
# https___download.eclipse.org_releases_2020-06_202006171000_artifacts.xml.xz
# https___download.eclipse.org_releases_2020-06_202006171000_content.xml.xz
# https___download.eclipse.org_releases_2020-06_202006171000_p2.index
# https___download.eclipse.org_releases_2020-06_compositeArtifacts.jar
# https___download.eclipse.org_releases_2020-06_compositeContent.jar
# https___download.eclipse.org_releases_2020-06_p2.index
# https___download.eclipse.org_releases_2020-09_202009161000_artifacts.xml.xz
# https___download.eclipse.org_releases_2020-09_202009161000_content.xml.xz
# https___download.eclipse.org_releases_2020-09_202009161000_p2.index
# https___download.eclipse.org_releases_2020-09_compositeArtifacts.jar
# https___download.eclipse.org_releases_2020-09_compositeContent.jar
# https___download.eclipse.org_releases_2020-09_p2.index
# https___download.eclipse.org_releases_latest_compositeArtifacts.jar
# https___download.eclipse.org_releases_latest_compositeContent.jar
# https___download.eclipse.org_releases_latest_p2.index
# https___download.eclipse.org_technology_epp_packages_2020-03_artifacts.jar.downloading
# https___download.eclipse.org_technology_epp_packages_2020-03_content.jar
# https___download.eclipse.org_technology_epp_packages_2020-03_p2.index
# https___download.eclipse.org_technology_epp_packages_2020-06_artifacts.jar
# https___download.eclipse.org_technology_epp_packages_2020-06_content.jar
# https___download.eclipse.org_technology_epp_packages_2020-06_p2.index
# https___download.eclipse.org_technology_epp_packages_2020-09_202009101200_artifacts.jar
# https___download.eclipse.org_technology_epp_packages_2020-09_202009101200_content.jar
# https___download.eclipse.org_technology_epp_packages_2020-09_202009101200_p2.index
# https___download.eclipse.org_technology_epp_packages_2020-09_compositeArtifacts.jar
# https___download.eclipse.org_technology_epp_packages_2020-09_compositeContent.jar
# https___download.eclipse.org_technology_epp_packages_2020-09_p2.index
# https___download.jetbrains.com_kotlin_eclipse-plugin_0.8.21_artifacts.jar
# https___download.jetbrains.com_kotlin_eclipse-plugin_0.8.21_content.jar
# https___download.jetbrains.com_kotlin_eclipse-plugin_0.8.21_p2.index
# https___download.jetbrains.com_kotlin_eclipse-plugin_last_compositeArtifacts.xml
# https___download.jetbrains.com_kotlin_eclipse-plugin_last_compositeContent.xml
# https___download.jetbrains.com_kotlin_eclipse-plugin_last_p2.index
# http___dl.bintray.com_jetbrains_kotlin_eclipse-plugin_0.8.21_artifacts.jar
# http___dl.bintray.com_jetbrains_kotlin_eclipse-plugin_0.8.21_content.jar
# http___dl.bintray.com_jetbrains_kotlin_eclipse-plugin_0.8.21_p2.index
# http___download.eclipse.org_eclipse_updates_4.14_categories_content.jar
# http___download.eclipse.org_eclipse_updates_4.14_categories_p2.index
# http___download.eclipse.org_eclipse_updates_4.14_compositeArtifacts.jar
# http___download.eclipse.org_eclipse_updates_4.14_compositeContent.jar
# http___download.eclipse.org_eclipse_updates_4.14_p2.index
# http___download.eclipse.org_eclipse_updates_4.14_R-4.14-201912100610_artifacts.xml.xz
# http___download.eclipse.org_eclipse_updates_4.14_R-4.14-201912100610_content.xml.xz
# http___download.eclipse.org_eclipse_updates_4.14_R-4.14-201912100610_p2.index
# http___download.eclipse.org_eclipse_updates_4.16_categories_content.jar
# http___download.eclipse.org_eclipse_updates_4.16_categories_p2.index
# http___download.eclipse.org_eclipse_updates_4.16_compositeArtifacts.jar
# http___download.eclipse.org_eclipse_updates_4.16_compositeContent.jar
# http___download.eclipse.org_eclipse_updates_4.16_p2.index
# http___download.eclipse.org_eclipse_updates_4.16_R-4.16-202006040540_artifacts.xml.xz
# http___download.eclipse.org_eclipse_updates_4.16_R-4.16-202006040540_content.xml.xz
# http___download.eclipse.org_eclipse_updates_4.16_R-4.16-202006040540_p2.index
# http___download.eclipse.org_eclipse_updates_4.17_categories_content.jar
# http___download.eclipse.org_eclipse_updates_4.17_categories_p2.index
# http___download.eclipse.org_eclipse_updates_4.17_compositeArtifacts.jar
# http___download.eclipse.org_eclipse_updates_4.17_compositeContent.jar
# http___download.eclipse.org_eclipse_updates_4.17_p2.index
# http___download.eclipse.org_eclipse_updates_4.17_R-4.17-202009021800_artifacts.xml.xz
# http___download.eclipse.org_eclipse_updates_4.17_R-4.17-202009021800_content.xml
# http___download.eclipse.org_eclipse_updates_4.17_R-4.17-202009021800_p2.index
# http___download.eclipse.org_oomph_drops_milestone_S20200304-074842-1.16.0-RC1_artifacts.jar
# http___download.eclipse.org_oomph_drops_milestone_S20200304-074842-1.16.0-RC1_content.jar
# http___download.eclipse.org_oomph_drops_milestone_S20200304-074842-1.16.0-RC1_p2.index
# http___download.eclipse.org_oomph_drops_milestone_S20200603-054423-1.17.0-RC1_artifacts.xml.xz
# http___download.eclipse.org_oomph_drops_milestone_S20200603-054423-1.17.0-RC1_content.xml.xz
# http___download.eclipse.org_oomph_drops_milestone_S20200603-054423-1.17.0-RC1_p2.index
# http___download.eclipse.org_oomph_drops_milestone_S20200715-042823-1.18.0-M1_artifacts.xml.xz
# http___download.eclipse.org_oomph_drops_milestone_S20200715-042823-1.18.0-M1_content.xml.xz
# http___download.eclipse.org_oomph_drops_milestone_S20200715-042823-1.18.0-M1_p2.index
# http___download.eclipse.org_oomph_drops_milestone_S20200825-014448-1.18.0-M3_artifacts.xml.xz
# http___download.eclipse.org_oomph_drops_milestone_S20200825-014448-1.18.0-M3_content.xml.xz
# http___download.eclipse.org_oomph_drops_milestone_S20200825-014448-1.18.0-M3_p2.index
# http___download.eclipse.org_oomph_drops_release_1.17.0_artifacts.xml.xz
# http___download.eclipse.org_oomph_drops_release_1.17.0_content.xml.xz
# http___download.eclipse.org_oomph_drops_release_1.17.0_p2.index
# http___download.eclipse.org_oomph_drops_release_1.18.0_artifacts.xml.xz
# http___download.eclipse.org_oomph_drops_release_1.18.0_content.xml.xz
# http___download.eclipse.org_oomph_drops_release_1.18.0_p2.index
# http___download.eclipse.org_oomph_drops_release_1.19.0_artifacts.xml.xz
# http___download.eclipse.org_oomph_drops_release_1.19.0_content.xml.xz
# http___download.eclipse.org_oomph_drops_release_1.19.0_p2.index
# http___download.eclipse.org_oomph_products_repository_artifacts.jar
# http___download.eclipse.org_oomph_products_repository_content.jar
# http___download.eclipse.org_oomph_products_repository_p2.index
# http___download.eclipse.org_oomph_updates_milestone_latest_compositeArtifacts.jar
# http___download.eclipse.org_oomph_updates_milestone_latest_compositeContent.jar
# http___download.eclipse.org_oomph_updates_milestone_latest_p2.index
# http___download.eclipse.org_releases_2019-12_201912181000_artifacts.xml.xz
# http___download.eclipse.org_releases_2019-12_201912181000_content.xml.xz
# http___download.eclipse.org_releases_2019-12_201912181000_p2.index
# http___download.eclipse.org_releases_2019-12_compositeArtifacts.jar
# http___download.eclipse.org_releases_2019-12_compositeContent.jar
# http___download.eclipse.org_releases_2019-12_p2.index
# http___download.eclipse.org_releases_2020-06_202006171000_artifacts.xml.xz
# http___download.eclipse.org_releases_2020-06_202006171000_content.xml.xz
# http___download.eclipse.org_releases_2020-06_202006171000_p2.index
# http___download.eclipse.org_releases_2020-06_compositeArtifacts.jar
# http___download.eclipse.org_releases_2020-06_compositeContent.jar
# http___download.eclipse.org_releases_2020-06_p2.index
# http___download.eclipse.org_releases_2020-09_202009161000_artifacts.xml.xz
# http___download.eclipse.org_releases_2020-09_202009161000_content.xml.xz
# http___download.eclipse.org_releases_2020-09_202009161000_p2.index
# http___download.eclipse.org_releases_2020-09_compositeArtifacts.jar
# http___download.eclipse.org_releases_2020-09_compositeContent.jar
# http___download.eclipse.org_releases_2020-09_p2.index
# http___download.eclipse.org_releases_latest_compositeArtifacts.jar
# http___download.eclipse.org_releases_latest_compositeContent.jar
# http___download.eclipse.org_releases_latest_p2.index
# http___download.eclipse.org_technology_epp_packages_2019-12_artifacts.xml.xz
# http___download.eclipse.org_technology_epp_packages_2019-12_content.xml.xz
# http___download.eclipse.org_technology_epp_packages_2019-12_p2.index
# http___download.eclipse.org_technology_epp_packages_2020-06_artifacts.jar
# http___download.eclipse.org_technology_epp_packages_2020-06_content.jar
# http___download.eclipse.org_technology_epp_packages_2020-06_p2.index
# http___download.eclipse.org_technology_epp_packages_2020-09_202009101200_artifacts.jar
# http___download.eclipse.org_technology_epp_packages_2020-09_202009101200_content.jar
# http___download.eclipse.org_technology_epp_packages_2020-09_202009101200_p2.index
# http___download.eclipse.org_technology_epp_packages_2020-09_compositeArtifacts.jar
# http___download.eclipse.org_technology_epp_packages_2020-09_compositeContent.jar
# http___download.eclipse.org_technology_epp_packages_2020-09_p2.index
# https___www.eclipse.org_setups_setups.zip
# https___www.eclipse.org_setups_setups.zip.etag
# http___www.eclipse.org_setups_setups.zip
# http___www.eclipse.org_setups_setups.zip.etag
# brandingNotificationURIs.txt
# catalogs.setup
# com.github.projects.setup
# indices.xmi
# locations.setup
# org.eclipse.projects.setup
# user.products.setup
# user.setup
# installRoot.txt
# frostwire.props
# installation.props
# intent.props
# itunes.props
# itunes_import.js
# itunes_remove_playlist.js
# questions.props
# tables.props
# crawldb.mv.db
# aint_no_love_tears_of_joy_overlay.jpg
# cyberghost_promo_dec_13_2018.jpg
# doobie_land_of_3s_overlay.jpg
# frostwire_creative_commons_mixtape_vol_6.jpg
# fw_desktop_android_ad_1.jpg
# fw_desktop_android_ad_3.jpg
# grafh_love_drugs_and_hennessy_overlay_2.jpg
# jekk_strong_frostwire_overlay.jpg
# joe_marson_overlay.jpg
# joe_playo_summer_of_joe_overlay.jpg
# just_matthew_connery_overlay.jpg
# lisa_richards_beating_of_the_sun_overlay.jpg
# liza_february_29_overlay_1.jpg
# steal_this_show_scuttlebutt_sep_2018.png
# the_bourgeois_overlay.jpg
# the_polish_ambassador_overlay_1.jpg
# twin_berlin_sleazebrain_overlay.jpg
# wasaru_sadtimes_overlay_1.jpg
# wasaru_sadtimes_overlay_2.jpg
# wildlight_hers_was_as_thund_overlay.jpg
# library_db.mv.db
# segments.gen
# segments_1
# 4b7fe21875fba628704475a90aef02988f51e93f.resume
# 4b7fe21875fba628704475a90aef02988f51e93f.torrent
# settings.dat
# gc.properties
# executionHistory.bin
# executionHistory.lock
# last-build.bin
# fileContent.lock
# fileHashes.bin
# fileHashes.lock
# resourceHashesCache.bin
# md-rule.lock
# md-supplier.lock
# cache.properties
# cp_init6418c6d726070f323dbddda2aadc82ef.lock
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# initfd756723fbe8af385d6851f9ab8e581f.lock
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# cp_init6418c6d726070f323dbddda2aadc82ef.lock
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# initc5ce93d6dd0450a2eb3466947f68ac65.lock
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# cp_init6418c6d726070f323dbddda2aadc82ef.lock
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# init345dafe9a9b1feed1e3cdd1aa6dc0ba5.lock
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# cp_settings6418c6d726070f323dbddda2aadc82ef.lock
# metadata.bin
# cache.properties
# settings6418c6d726070f323dbddda2aadc82ef.lock
# metadata.bin
# _BuildScript_.class
# cache.properties
# cp_settings6418c6d726070f323dbddda2aadc82ef.lock
# metadata.bin
# cache.properties
# settings6418c6d726070f323dbddda2aadc82ef.lock
# metadata.bin
# _BuildScript_.class
# cache.properties
# cp_proj6418c6d726070f323dbddda2aadc82ef.lock
# metadata.bin
# cache.properties
# projb68d9c8ba95b37773d2dfd6782aeb03c.lock
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure5.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# cache.properties
# cp_proj6418c6d726070f323dbddda2aadc82ef.lock
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# projb68d9c8ba95b37773d2dfd6782aeb03c.lock
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# cache.properties
# cp_proj6418c6d726070f323dbddda2aadc82ef.lock
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# proj8c8d1bc5fe8d7923aad155cf4fb2a3b0.lock
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure7.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1$_closure6.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# cache.properties
# cp_init6418c6d726070f323dbddda2aadc82ef.lock
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# init963e35b8eda1e901a45e9481da3db6a0.lock
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# cp_proj6418c6d726070f323dbddda2aadc82ef.lock
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# proj8c8d1bc5fe8d7923aad155cf4fb2a3b0.lock
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# gc.properties
# executionHistory.bin
# executionHistory.lock
# last-build.bin
# fileContent.lock
# fileHashes.bin
# fileHashes.lock
# resourceHashesCache.bin
# jarAnalysis.bin
# javaCompile.lock
# md-rule.bin
# md-rule.lock
# md-supplier.lock
# 15emg32vbej636y8th3rnwqc.lock
# cache.properties
# metadata.bin
# 19tqzzo25g4iqjxh051obw28n.lock
# cache.properties
# metadata.bin
# _BuildScript_.class
# 1s6hmrdsb4hu9354s0f1unx6o.lock
# cache.properties
# metadata.bin
# _BuildScript_.class
# 1ui8vikrlhp2opn8q39zefdqc.lock
# cache.properties
# metadata.bin
# _BuildScript_.class
# 24n89bzbyrqpwoiw92wymmoi3.lock
# cache.properties
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 2eznkenlg6pg9bime6tixmtuo.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 2qceohpxmo00t2vxbl6zj528j.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 2yg7ypn5rs63wx77mlw0a95lf.lock
# cache.properties
# metadata.bin
# _BuildScript_.class
# 31t1hc7qyss9na3qlweowf4da.lock
# cache.properties
# metadata.bin
# _BuildScript_.class
# 3a7evla54byz8cwr12s8fl6y8.lock
# cache.properties
# metadata.bin
# _BuildScript_.class
# 3e1x6h3pf62t7ma42rswqr456.lock
# cache.properties
# metadata.bin
# 47g5vujckp9riof681kpozd3l.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# 48b1wpe51ujz4exd86joixsqv.lock
# cache.properties
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# 48pyrrminwb4itjjew09od4i1.lock
# cache.properties
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# 4vf6ottr1ifhpbxkn5o02j0es.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 4xgtixnzbjf42ryk1xewlpd2o.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 5iago88aw79f3gymnp1ggqljn.lock
# cache.properties
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# 5pzer9v7gyyibgcyc187veyiq.lock
# cache.properties
# metadata.bin
# 5uar14ww28v8kzo9xyg2mr53a.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# 5vdrj3n3znmt0c6r3bc6spwyw.lock
# cache.properties
# metadata.bin
# 5ytoqcakl9m09tcm87vw8yv3f.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 610hd0xz46b1x8xnjyvw5783o.lock
# cache.properties
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 62qguv4ycoadnoeeo07pzhzk.lock
# cache.properties
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# 6lejom69sx6qadxi8ndrtz7q3.lock
# cache.properties
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# 6scdgc57npt1yn0jcd3aj3ame.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 6ssbca37584ws57nqs7vni7zt.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# 6uo7m85veijjvi9owjarxhp2w.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 6vjpqscw58aio3qe9acs4hjdy.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# 72fwf0mqzn16cl99pikglk1eb.lock
# cache.properties
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 72ynl6xvcnssi4rconsrge948.lock
# cache.properties
# metadata.bin
# 73gmnknhuftrxzk3dgcsfxw82.lock
# cache.properties
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# 772w8bv8zotlxp9hezanuxerf.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 7krgtm8xr6co4gof35vqebd50.lock
# cache.properties
# metadata.bin
# _BuildScript_.class
# 7ri92kfczel2ve47u036ik2sf.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 7xta2gvoas66eg21c61rkmed3.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# 80nvgjp1cb713mc201fjlkdao.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 80z89zj61x7sxnlokjqynrp1e.lock
# cache.properties
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 81nhu1enz4wb5rzn83ixo6yos.lock
# cache.properties
# metadata.bin
# _BuildScript_.class
# 852rw3ujhfnu6vo41k8e2cwiz.lock
# cache.properties
# metadata.bin
# 855tfv6dqhegfsdph3y14tosh.lock
# cache.properties
# metadata.bin
# 8bq1ipo11jubpwzlugjurv32o.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# 8cfzt9goc7romtjjthmkqe5sl.lock
# cache.properties
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 8d34xcbvc1mo7jg9zaj5t7urt.lock
# cache.properties
# metadata.bin
# 8f0bda6z8vi28m57xjgciv7h5.lock
# cache.properties
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 8gw472cfllt6xin88sxf35n9z.lock
# cache.properties
# metadata.bin
# _BuildScript_.class
# 8hmv9ciq8hxudkoyz06ctv5q8.lock
# cache.properties
# metadata.bin
# _BuildScript_.class
# 8jucwrv59nuxpkzxgkamef2mw.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# 8l9idbsv5pan5rylgwg2hn9kj.lock
# cache.properties
# metadata.bin
# 9foqha46bqz71f1q5k11upqw5.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# 9gxlboyi6xppf5dxh3ilblgd6.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# 9h6res4ycimcc2d5qeryttpm1.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# ac3kvjkr2fepcxahadc0m5gmd.lock
# cache.properties
# metadata.bin
# adj5a6qyywflegshalw7sskux.lock
# cache.properties
# metadata.bin
# adljs5upw67nvr1csa3yke2cb.lock
# cache.properties
# metadata.bin
# almtijwwc5ov1ltybym90sdfq.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# asmx2qamgxjtin2fcv4vhx4vb.lock
# cache.properties
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# ayq3y5jxauiivn77ukz8s4d1i.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# b7p04wfzzmezkd7ns8d58wtxd.lock
# cache.properties
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# bkizx31gixtfpkurj8vzgdqqn.lock
# cache.properties
# metadata.bin
# bl3jh59ij3t3tuxfk8vksxvuu.lock
# cache.properties
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# bq9b7p09msyqrgva7fpfmrlr8.lock
# cache.properties
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# bzuzxjox94me9rwevy3jntym4.lock
# cache.properties
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# c8qb0986kkv6p9cj9olkhr4po.lock
# cache.properties
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# ccsl9amfs7y6jbvvihmyzqicl.lock
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# cache.properties
# cdz2o8ztr3qraszluske5p434.lock
# metadata.bin
# _BuildScript_.class
# cache.properties
# cl6ixgb99e4abohlptswfbwb3.lock
# metadata.bin
# _BuildScript_.class
# cache.properties
# d77osub5hr0bu7npmjxxm0wjc.lock
# metadata.bin
# _BuildScript_.class
# cache.properties
# dec4g7jdb789bm5q8d7r0buhv.lock
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# du9e0gqqeij7yeh10he2uw33d.lock
# JetGradlePlugin$_apply_closure1$_closure2$_closure3.class
# JetGradlePlugin$_apply_closure1$_closure2.class
# JetGradlePlugin$_apply_closure1.class
# JetGradlePlugin.class
# RegistryProcessor$_extraModelBuilderIsRegistered_closure1.class
# RegistryProcessor.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# e7nxkk61f2kzip7mbpa6o0anm.lock
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# cache.properties
# e82chpgruxqo7q6j2pv2dcu98.lock
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# e840yv7tqtw72zlyzwbdu3028.lock
# _BuildScript_$_run_closure1$_closure2.class
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# eiqdtocnvgo85lyvx1emgjy8a.lock
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# cache.properties
# ev3uzq46z1x796iw0tg40zwsd.lock
# metadata.bin
# _BuildScript_$_run_closure1$_closure3.class
# _BuildScript_$_run_closure1$_closure4$_closure6.class
# _BuildScript_$_run_closure1$_closure4.class
# _BuildScript_$_run_closure1$_closure5.class
# _BuildScript_$_run_closure1.class
# _BuildScript_$_run_closure2.class
# _BuildScript_.class
# cache.properties
# f11ihe8abmdlstuiwtyjq246i.lock
# _BuildScript_$_run_closure1.class
# _BuildScript_.class
# metadata.bin
# gc.properties
# jars-8.lock
# cp_proj.jar
# kotlin-stdlib-1.4.31.jar
# FastInfoset-1.2.16.jar
# proj.jar
# cp_settings.jar
# failureaccess-1.0.1.jar
# cp_settings.jar
# cp_proj.jar
# sdklib-27.2.2.jar
# builder-model-4.2.2.jar
# cp_proj.jar
# javawriter-2.5.0.jar
# trove4j.jar
# proj.jar
# settings.jar
# manifest-merger-27.2.2.jar
# proj.jar
# kotlin-reflect-1.4.31.jar
# bcpkix-jdk15on-1.56.jar
# xercesImpl-2.12.0.jar
# zipflinger-4.2.2.jar
# gradle-api-4.2.2.jar
# javax.inject-1.jar
# kotlin-stdlib-jdk8-1.4.31.jar
# bcprov-jdk15on-1.56.jar
# cp_settings.jar
# builder-4.2.2.jar
# commons-logging-1.2.jar
# proj.jar
# proguard-base-6.0.3.jar
# ion-java-1.5.2-2.jar
# jna-5.6.0.jar
# core-proto-0.0.8-alpha01.jar
# fastutil-8.4.0.jar
# jdom2-2.0.6.jar
# cp_init.jar
# cp_proj.jar
# commons-codec-1.10.jar
# cp_proj.jar
# kotlin-compiler-plugins-lombok.jar
# dvlib-27.2.2.jar
# builder-test-api-4.2.2.jar
# protobuf-java-util-3.10.0.jar
# annotations-13.0.jar
# gradle-tooling-extension-impl.jar
# juniversalchardet-1.0.3.jar
# antlr4-4.5.3.jar
# tracker-27.2.2.jar
# guava-28.1-jre.jar
# aaptcompiler-4.2.2.jar
# jaxb-runtime-2.3.2.jar
# cp_settings.jar
# error_prone_annotations-2.3.2.jar
# apkzlib-4.2.2.jar
# kotlin-stdlib-jdk7-1.4.31.jar
# common-27.2.2.jar
# protos-27.2.2.jar
# kotlin-compiler-plugins-annotation-based-compiler-support.jar
# kotlin-stdlib-1.4.31.jar
# trove4j-1.0.20181211.jar
# xml-apis-1.4.01.jar
# settings.jar
# proj.jar
# tensorflow-lite-metadata-0.1.0-rc2.jar
# kotlin-stdlib-common-1.4.31.jar
# cp_init.jar
# apksig-4.2.2.jar
# proj.jar
# istack-commons-runtime-3.0.8.jar
# gradle-4.2.2.jar
# checker-qual-2.8.1.jar
# gson-2.8.6.jar
# signflinger-4.2.2.jar
# settings.jar
# jimfs-1.1.jar
# cp_proj.jar
# layoutlib-api-27.2.2.jar
# commons-io-2.4.jar
# cp_settings.jar
# cp_settings.jar
# proj.jar
# cp_proj.jar
# cp_init.jar
# shared-27.2.2.jar
# gradle-api-impldep-6.5.jar
# stax-ex-1.8.1.jar
# httpmime-4.5.6.jar
# asm-analysis-7.0.jar
# jetifier-core-1.0.0-beta09.jar
# settings.jar
# cp_proj.jar
# proj.jar
# cp_settings.jar
# transform-api-2.0.0-deprecated-use-gradle-api.jar
# proj.jar
# cp_init.jar
# kxml2-2.3.0.jar
# json-simple-1.1.jar
# animal-sniffer-annotations-1.18.jar
# proguard-gradle-6.0.3.jar
# cp_proj.jar
# cp_proj.jar
# cp_init.jar
# proj.jar
# asm-7.0.jar
# baseLibrary-4.2.2.jar
# cp_init.jar
# cp_proj.jar
# tink-1.3.0-rc2.jar
# cp_init.jar
# jakarta.activation-api-1.2.1.jar
# cp_proj.jar
# repository-27.2.2.jar
# j2objc-annotations-1.3.jar
# json-20180813.jar
# ddmlib-27.2.2.jar
# httpcore-4.4.10.jar
# proj.jar
# crash-27.2.2.jar
# proj.jar
# init.jar
# javax.activation-1.2.0.jar
# javapoet-1.10.0.jar
# cp_init.jar
# settings.jar
# proj.jar
# jna-platform-5.6.0.jar
# proj.jar
# txw2-2.3.2.jar
# gradle-tooling-extension-api.jar
# cp_proj.jar
# cp_proj.jar
# jetifier-processor-1.0.0-beta09.jar
# settings.jar
# proj.jar
# proj.jar
# init.jar
# kotlin-gradle-gradle-tooling.jar
# protobuf-java-3.10.0.jar
# dagger-2.28.3.jar
# databinding-common-4.2.2.jar
# jsr305-3.0.2.jar
# jakarta.xml.bind-api-2.3.2.jar
# proj.jar
# cp_settings.jar
# android-extensions-ide.jar
# aapt2-proto-4.2.2-7147631.jar
# databinding-compiler-common-4.2.2.jar
# flatbuffers-java-1.12.0.jar
# asm-util-7.0.jar
# external-system-rt.jar
# asm-tree-7.0.jar
# listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar
# android.jar
# jopt-simple-4.9.jar
# cp_proj.jar
# httpclient-4.5.6.jar
# util.jar
# auto-value-annotations-1.6.2.jar
# cp_proj.jar
# cp_init.jar
# settings.jar
# annotations-27.2.2.jar
# lint-model-27.2.2.jar
# asm-commons-7.0.jar
# commons-compress-1.12.jar
# settings.jar
# sdk-common-27.2.2.jar
# init.jar
# lint-gradle-api-27.2.2.jar
# bundletool-1.1.0.jar
# android-base-common.jar
# sdk-common.jar
# util.jar
# ion-java-1.5.2-2.jar
# gradle-appengine-builder-model-0.1.0.jar
# gradle-api-impldep-6.5.jar
# gradle-tooling-extension-impl.jar
# gradle-tooling-extension-api.jar
# kotlin-stdlib.jar
# kotlin-stdlib-1.4.31.jar
# gradle-toolingLoaderRt.jar
# kotlin-gradle-gradle-tooling.jar
# android-extensions-ide.jar
# trove4j.jar
# gradle-api-6.5.jar
# sdk-tools.jar
# android.jar
# external-system-rt.jar
# annotations-java5.jar
# guava-29.0-jre.jar
# repository.jar
# file-access.bin
# file-access.properties
# journal-1.lock
# gc.properties
# modules-2.lock
# activity-1.0.0-sources.jar
# activity-1.0.0.aar
# activity-1.0.0.pom
# activity-1.2.3.aar
# activity-1.2.3.module
# activity-1.2.3-sources.jar
# activity-1.2.3.pom
# activity-1.2.4-sources.jar
# activity-1.2.4.aar
# activity-1.2.4.pom
# activity-1.2.4.module
# annotation-1.1.0.pom
# annotation-1.1.0-javadoc.jar
# annotation-1.1.0-sources.jar
# annotation-1.1.0.jar
# annotation-1.2.0.module
# annotation-1.2.0.jar
# annotation-1.2.0-sources.jar
# annotation-1.2.0.pom
# annotation-experimental-1.0.0-sources.jar
# annotation-experimental-1.0.0.pom
# annotation-experimental-1.0.0.aar
# appcompat-1.2.0-sources.jar
# appcompat-1.2.0.module
# appcompat-1.2.0.aar
# appcompat-1.2.0.pom
# appcompat-1.3.0-sources.jar
# appcompat-1.3.0.aar
# appcompat-1.3.0.pom
# appcompat-1.3.0.module
# appcompat-1.3.1-sources.jar
# appcompat-1.3.1.pom
# appcompat-1.3.1.module
# appcompat-1.3.1.aar
# appcompat-resources-1.2.0.pom
# appcompat-resources-1.2.0.module
# appcompat-resources-1.2.0-sources.jar
# appcompat-resources-1.2.0.aar
# appcompat-resources-1.3.0.module
# appcompat-resources-1.3.0.pom
# appcompat-resources-1.3.0-sources.jar
# appcompat-resources-1.3.0.aar
# appcompat-resources-1.3.1.aar
# appcompat-resources-1.3.1.module
# appcompat-resources-1.3.1-sources.jar
# appcompat-resources-1.3.1.pom
# core-common-2.0.1.pom
# core-common-2.1.0.pom
# core-common-2.1.0-sources.jar
# core-common-2.1.0.jar
# core-runtime-2.0.0-sources.jar
# core-runtime-2.0.0.aar
# core-runtime-2.0.0.pom
# core-runtime-2.1.0.aar
# core-runtime-2.1.0.pom
# core-runtime-2.1.0-sources.jar
# asynclayoutinflater-1.0.0.aar
# asynclayoutinflater-1.0.0-sources.jar
# asynclayoutinflater-1.0.0.pom
# cardview-1.0.0.aar
# cardview-1.0.0.pom
# cardview-1.0.0-sources.jar
# collection-1.1.0.jar
# collection-1.1.0-sources.jar
# collection-1.1.0.pom
# constraintlayout-2.0.1.pom
# constraintlayout-2.0.1.aar
# constraintlayout-2.0.4.pom
# constraintlayout-2.0.4.aar
# constraintlayout-2.1.0.module
# constraintlayout-2.1.0.pom
# constraintlayout-2.1.0-sources.jar
# constraintlayout-2.1.0.aar
# constraintlayout-core-1.0.0.jar
# constraintlayout-core-1.0.0.module
# constraintlayout-core-1.0.0.pom
# constraintlayout-solver-2.0.1.jar
# constraintlayout-solver-2.0.1.pom
# constraintlayout-solver-2.0.4.jar
# constraintlayout-solver-2.0.4.pom
# coordinatorlayout-1.1.0.pom
# coordinatorlayout-1.1.0.aar
# coordinatorlayout-1.1.0-sources.jar
# core-1.3.0.pom
# core-1.3.1.aar
# core-1.3.1.pom
# core-1.3.1-sources.jar
# core-1.5.0.pom
# core-1.5.0.aar
# core-1.5.0.module
# core-1.5.0-sources.jar
# cursoradapter-1.0.0-sources.jar
# cursoradapter-1.0.0.aar
# cursoradapter-1.0.0.pom
# customview-1.0.0.aar
# customview-1.0.0.pom
# customview-1.0.0-sources.jar
# databinding-common-4.2.2-sources.jar
# databinding-common-4.2.2.pom
# databinding-common-4.2.2.module
# databinding-common-4.2.2.jar
# databinding-compiler-common-4.2.2-sources.jar
# databinding-compiler-common-4.2.2.module
# databinding-compiler-common-4.2.2.jar
# databinding-compiler-common-4.2.2.pom
# documentfile-1.0.0.aar
# documentfile-1.0.0.pom
# documentfile-1.0.0-sources.jar
# drawerlayout-1.0.0.pom
# drawerlayout-1.0.0-sources.jar
# drawerlayout-1.0.0.aar
# dynamicanimation-1.0.0-sources.jar
# dynamicanimation-1.0.0.pom
# dynamicanimation-1.0.0.aar
# fragment-1.1.0.aar
# fragment-1.1.0.pom
# fragment-1.1.0-sources.jar
# fragment-1.3.4.aar
# fragment-1.3.4.pom
# fragment-1.3.4.module
# fragment-1.3.4-sources.jar
# fragment-1.3.6-sources.jar
# fragment-1.3.6.pom
# fragment-1.3.6.aar
# fragment-1.3.6.module
# gridlayout-1.0.0.aar
# gridlayout-1.0.0-sources.jar
# gridlayout-1.0.0.pom
# interpolator-1.0.0.aar
# interpolator-1.0.0.pom
# interpolator-1.0.0-sources.jar
# legacy-support-core-ui-1.0.0.aar
# legacy-support-core-ui-1.0.0.pom
# legacy-support-core-ui-1.0.0-sources.jar
# legacy-support-core-utils-1.0.0-sources.jar
# legacy-support-core-utils-1.0.0.pom
# legacy-support-core-utils-1.0.0.aar
# lifecycle-common-2.1.0.jar
# lifecycle-common-2.1.0.pom
# lifecycle-common-2.1.0-sources.jar
# lifecycle-common-2.3.1-sources.jar
# lifecycle-common-2.3.1.module
# lifecycle-common-2.3.1.pom
# lifecycle-common-2.3.1.jar
# lifecycle-livedata-2.0.0-sources.jar
# lifecycle-livedata-2.0.0.pom
# lifecycle-livedata-2.0.0.aar
# lifecycle-livedata-core-2.0.0.aar
# lifecycle-livedata-core-2.0.0.pom
# lifecycle-livedata-core-2.0.0-sources.jar
# lifecycle-livedata-core-2.3.1.module
# lifecycle-livedata-core-2.3.1.pom
# lifecycle-livedata-core-2.3.1-sources.jar
# lifecycle-livedata-core-2.3.1.aar
# lifecycle-runtime-2.1.0.aar
# lifecycle-runtime-2.1.0-sources.jar
# lifecycle-runtime-2.1.0.pom
# lifecycle-runtime-2.3.1.aar
# lifecycle-runtime-2.3.1.pom
# lifecycle-runtime-2.3.1-sources.jar
# lifecycle-runtime-2.3.1.module
# lifecycle-viewmodel-2.1.0.aar
# lifecycle-viewmodel-2.1.0.pom
# lifecycle-viewmodel-2.1.0-sources.jar
# lifecycle-viewmodel-2.3.1.pom
# lifecycle-viewmodel-2.3.1.module
# lifecycle-viewmodel-2.3.1-sources.jar
# lifecycle-viewmodel-2.3.1.aar
# lifecycle-viewmodel-savedstate-2.3.1-sources.jar
# lifecycle-viewmodel-savedstate-2.3.1.pom
# lifecycle-viewmodel-savedstate-2.3.1.module
# lifecycle-viewmodel-savedstate-2.3.1.aar
# loader-1.0.0.pom
# loader-1.0.0.aar
# loader-1.0.0-sources.jar
# localbroadcastmanager-1.0.0.aar
# localbroadcastmanager-1.0.0-sources.jar
# localbroadcastmanager-1.0.0.pom
# print-1.0.0-sources.jar
# print-1.0.0.aar
# print-1.0.0.pom
# recyclerview-1.1.0.aar
# recyclerview-1.1.0.pom
# recyclerview-1.1.0-sources.jar
# savedstate-1.0.0.pom
# savedstate-1.0.0.aar
# savedstate-1.0.0-sources.jar
# savedstate-1.1.0-sources.jar
# savedstate-1.1.0.aar
# savedstate-1.1.0.pom
# savedstate-1.1.0.module
# slidingpanelayout-1.0.0.aar
# slidingpanelayout-1.0.0.pom
# slidingpanelayout-1.0.0-sources.jar
# swiperefreshlayout-1.0.0.aar
# swiperefreshlayout-1.0.0.pom
# swiperefreshlayout-1.0.0-sources.jar
# core-1.3.0-javadoc.jar
# core-1.3.0.pom
# core-1.3.0.aar
# core-1.3.0-sources.jar
# core-1.4.0-sources.jar
# core-1.4.0.pom
# core-1.4.0-javadoc.jar
# core-1.4.0.aar
# monitor-1.3.0-javadoc.jar
# monitor-1.3.0.pom
# monitor-1.3.0-sources.jar
# monitor-1.3.0.aar
# monitor-1.4.0.pom
# monitor-1.4.0-javadoc.jar
# monitor-1.4.0.aar
# monitor-1.4.0-sources.jar
# runner-1.3.0-sources.jar
# runner-1.3.0.pom
# runner-1.3.0-javadoc.jar
# runner-1.3.0.aar
# runner-1.4.0-sources.jar
# runner-1.4.0.aar
# runner-1.4.0.pom
# runner-1.4.0-javadoc.jar
# espresso-core-3.3.0-sources.jar
# espresso-core-3.3.0.aar
# espresso-core-3.3.0.pom
# espresso-core-3.3.0-javadoc.jar
# espresso-core-3.4.0-javadoc.jar
# espresso-core-3.4.0.pom
# espresso-core-3.4.0-sources.jar
# espresso-core-3.4.0.aar
# espresso-idling-resource-3.3.0.aar
# espresso-idling-resource-3.3.0-javadoc.jar
# espresso-idling-resource-3.3.0.pom
# espresso-idling-resource-3.3.0-sources.jar
# espresso-idling-resource-3.4.0-javadoc.jar
# espresso-idling-resource-3.4.0-sources.jar
# espresso-idling-resource-3.4.0.pom
# espresso-idling-resource-3.4.0.aar
# junit-1.1.2.aar
# junit-1.1.2.pom
# junit-1.1.2-javadoc.jar
# junit-1.1.2-sources.jar
# junit-1.1.3.aar
# junit-1.1.3.pom
# junit-1.1.3-sources.jar
# junit-1.1.3-javadoc.jar
# storage-1.4.0.aar
# storage-1.4.0-sources.jar
# storage-1.4.0.pom
# tracing-1.0.0.aar
# tracing-1.0.0.pom
# tracing-1.0.0.module
# transition-1.2.0.pom
# transition-1.2.0.aar
# transition-1.2.0-sources.jar
# vectordrawable-1.1.0-sources.jar
# vectordrawable-1.1.0.pom
# vectordrawable-1.1.0.aar
# vectordrawable-animated-1.1.0.pom
# vectordrawable-animated-1.1.0-sources.jar
# vectordrawable-animated-1.1.0.aar
# versionedparcelable-1.1.0.pom
# versionedparcelable-1.1.0.aar
# versionedparcelable-1.1.0-sources.jar
# versionedparcelable-1.1.1.aar
# versionedparcelable-1.1.1.pom
# versionedparcelable-1.1.1-sources.jar
# viewpager-1.0.0.aar
# viewpager-1.0.0.pom
# viewpager-1.0.0-sources.jar
# viewpager2-1.0.0-sources.jar
# viewpager2-1.0.0.pom
# viewpager2-1.0.0.aar
# signflinger-4.2.2.module
# signflinger-4.2.2-sources.jar
# signflinger-4.2.2.pom
# signflinger-4.2.2.jar
# zipflinger-4.2.2.jar
# zipflinger-4.2.2.module
# zipflinger-4.2.2-sources.jar
# zipflinger-4.2.2.pom
# baseLibrary-4.2.2.pom
# baseLibrary-4.2.2-sources.jar
# baseLibrary-4.2.2.jar
# baseLibrary-4.2.2.module
# annotations-27.2.2-sources.jar
# annotations-27.2.2.module
# annotations-27.2.2.jar
# annotations-27.2.2.pom
# common-27.2.2.pom
# common-27.2.2.module
# common-27.2.2.jar
# common-27.2.2-sources.jar
# dvlib-27.2.2-sources.jar
# dvlib-27.2.2.jar
# dvlib-27.2.2.module
# dvlib-27.2.2.pom
# repository-27.2.2-sources.jar
# repository-27.2.2.jar
# repository-27.2.2.module
# repository-27.2.2.pom
# sdk-common-27.2.2-sources.jar
# sdk-common-27.2.2.jar
# sdk-common-27.2.2.pom
# sdk-common-27.2.2.module
# sdklib-27.2.2.jar
# sdklib-27.2.2.module
# sdklib-27.2.2-sources.jar
# sdklib-27.2.2.pom
# crash-27.2.2.pom
# crash-27.2.2-sources.jar
# crash-27.2.2.jar
# crash-27.2.2.module
# protos-27.2.2.module
# protos-27.2.2-sources.jar
# protos-27.2.2.pom
# protos-27.2.2.jar
# shared-27.2.2.pom
# shared-27.2.2.module
# shared-27.2.2.jar
# shared-27.2.2-sources.jar
# tracker-27.2.2-sources.jar
# tracker-27.2.2.jar
# tracker-27.2.2.pom
# tracker-27.2.2.module
# aapt2-4.2.2-7147631-windows.jar
# aapt2-4.2.2-7147631.pom
# aapt2-proto-4.2.2-7147631.jar
# aapt2-proto-4.2.2-7147631-sources.jar
# aapt2-proto-4.2.2-7147631.module
# aapt2-proto-4.2.2-7147631.pom
# aaptcompiler-4.2.2.module
# aaptcompiler-4.2.2-sources.jar
# aaptcompiler-4.2.2.pom
# aaptcompiler-4.2.2.jar
# apksig-4.2.2.pom
# apksig-4.2.2.jar
# apksig-4.2.2.module
# apksig-4.2.2-sources.jar
# apkzlib-4.2.2-sources.jar
# apkzlib-4.2.2.jar
# apkzlib-4.2.2.pom
# apkzlib-4.2.2.module
# builder-4.2.2-sources.jar
# builder-4.2.2.pom
# builder-4.2.2.jar
# builder-4.2.2.module
# builder-model-4.2.2.module
# builder-model-4.2.2.jar
# builder-model-4.2.2-sources.jar
# builder-model-4.2.2.pom
# builder-test-api-4.2.2.pom
# builder-test-api-4.2.2.jar
# builder-test-api-4.2.2-sources.jar
# builder-test-api-4.2.2.module
# bundletool-1.1.0.pom
# bundletool-1.1.0.jar
# gradle-4.2.2.module
# gradle-4.2.2.pom
# gradle-4.2.2.jar
# gradle-4.2.2-sources.jar
# gradle-api-4.2.2-sources.jar
# gradle-api-4.2.2.pom
# gradle-api-4.2.2.jar
# gradle-api-4.2.2.module
# manifest-merger-27.2.2-sources.jar
# manifest-merger-27.2.2.module
# manifest-merger-27.2.2.pom
# manifest-merger-27.2.2.jar
# transform-api-2.0.0-deprecated-use-gradle-api.jar
# transform-api-2.0.0-deprecated-use-gradle-api-sources.jar
# jetifier-core-1.0.0-beta09-sources.jar
# jetifier-core-1.0.0-beta09.jar
# jetifier-processor-1.0.0-beta09-sources.jar
# jetifier-processor-1.0.0-beta09.jar
# ddmlib-27.2.2-sources.jar
# ddmlib-27.2.2.pom
# ddmlib-27.2.2.module
# ddmlib-27.2.2.jar
# layoutlib-api-27.2.2.pom
# layoutlib-api-27.2.2.module
# layoutlib-api-27.2.2.jar
# layoutlib-api-27.2.2-sources.jar
# lint-gradle-api-27.2.2.jar
# lint-gradle-api-27.2.2-sources.jar
# lint-gradle-api-27.2.2.module
# lint-gradle-api-27.2.2.pom
# lint-model-27.2.2.pom
# lint-model-27.2.2.jar
# lint-model-27.2.2-sources.jar
# lint-model-27.2.2.module
# material-1.2.1.pom
# material-1.2.1.module
# material-1.2.1-sources.jar
# material-1.2.1.aar
# material-1.4.0.module
# material-1.4.0-sources.jar
# material-1.4.0.aar
# material-1.4.0.pom
# auto-parent-6.pom
# auto-value-annotations-1.6.2.pom
# auto-value-annotations-1.6.2-sources.jar
# auto-value-annotations-1.6.2.jar
# auto-value-parent-1.6.2.pom
# jsr305-1.3.9.pom
# jsr305-2.0.1.jar
# jsr305-2.0.1.pom
# jsr305-3.0.2.jar
# jsr305-3.0.2.pom
# jsr305-3.0.2-sources.jar
# gson-2.8.6-sources.jar
# gson-2.8.6.jar
# gson-2.8.6.pom
# gson-parent-2.8.6.pom
# tink-1.3.0-rc2-sources.jar
# tink-1.3.0-rc2.pom
# tink-1.3.0-rc2.jar
# dagger-2.28.3.jar
# dagger-2.28.3.pom
# dagger-2.28.3-sources.jar
# error_prone_annotations-2.3.1.pom
# error_prone_annotations-2.3.2-sources.jar
# error_prone_annotations-2.3.2.jar
# error_prone_annotations-2.3.2.pom
# error_prone_parent-2.3.1.pom
# error_prone_parent-2.3.2.pom
# flatbuffers-java-1.12.0-sources.jar
# flatbuffers-java-1.12.0.jar
# flatbuffers-java-1.12.0.pom
# failureaccess-1.0.1-sources.jar
# failureaccess-1.0.1.jar
# failureaccess-1.0.1.pom
# guava-28.1-jre.pom
# guava-28.1-jre-sources.jar
# guava-28.1-jre.jar
# guava-parent-26.0-android.pom
# guava-parent-28.1-jre.pom
# listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.pom
# listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar
# j2objc-annotations-1.3.pom
# j2objc-annotations-1.3.jar
# j2objc-annotations-1.3-sources.jar
# jimfs-1.1.pom
# jimfs-1.1.jar
# jimfs-1.1-sources.jar
# jimfs-parent-1.1.pom
# protobuf-bom-3.10.0.pom
# protobuf-java-3.10.0-sources.jar
# protobuf-java-3.10.0.jar
# protobuf-java-3.10.0.pom
# protobuf-java-util-3.10.0-sources.jar
# protobuf-java-util-3.10.0.jar
# protobuf-java-util-3.10.0.pom
# protobuf-parent-3.10.0.pom
# core-proto-0.0.8-alpha01-sources.jar
# core-proto-0.0.8-alpha01.pom
# core-proto-0.0.8-alpha01.jar
# json-simple-1.1-sources.jar
# json-simple-1.1.jar
# json-simple-1.1.pom
# juniversalchardet-1.0.3-sources.jar
# juniversalchardet-1.0.3.pom
# juniversalchardet-1.0.3.jar
# javapoet-1.10.0.pom
# javapoet-1.10.0-sources.jar
# javapoet-1.10.0.jar
# javawriter-2.1.1-sources.jar
# javawriter-2.1.1.jar
# javawriter-2.1.1.pom
# javawriter-2.1.1-javadoc.jar
# javawriter-2.5.0-sources.jar
# javawriter-2.5.0.jar
# javawriter-2.5.0.pom
# all-1.2.0.pom
# all-1.2.1.pom
# javax.activation-1.2.0-sources.jar
# javax.activation-1.2.0.pom
# javax.activation-1.2.0.jar
# istack-commons-3.0.8.pom
# istack-commons-runtime-3.0.8-sources.jar
# istack-commons-runtime-3.0.8.jar
# istack-commons-runtime-3.0.8.pom
# jaxb-bom-ext-2.3.2.pom
# jaxb-parent-2.3.2.pom
# jaxb-runtime-parent-2.3.2.pom
# jaxb-txw-parent-2.3.2.pom
# FastInfoset-1.2.16.jar
# FastInfoset-1.2.16-sources.jar
# FastInfoset-1.2.16.pom
# fastinfoset-project-1.2.16.pom
# commons-codec-1.10-sources.jar
# commons-codec-1.10.pom
# commons-codec-1.10.jar
# commons-io-2.4.pom
# commons-io-2.4.jar
# commons-io-2.4-sources.jar
# commons-logging-1.2.jar
# commons-logging-1.2.pom
# commons-logging-1.2-sources.jar
# fastutil-8.4.0-sources.jar
# fastutil-8.4.0.jar
# fastutil-8.4.0.pom
# jakarta.activation-api-1.2.1.jar
# jakarta.activation-api-1.2.1-sources.jar
# jakarta.activation-api-1.2.1.pom
# jakarta.xml.bind-api-2.3.2.pom
# jakarta.xml.bind-api-2.3.2.jar
# jakarta.xml.bind-api-2.3.2-sources.jar
# jakarta.xml.bind-api-parent-2.3.2.pom
# javax.inject-1.jar
# javax.inject-1-javadoc.jar
# javax.inject-1-sources.jar
# javax.inject-1.pom
# junit-4.12.jar
# junit-4.12.pom
# junit-4.12-javadoc.jar
# junit-4.12-sources.jar
# junit-4.13.2-sources.jar
# junit-4.13.2.pom
# junit-4.13.2.jar
# junit-4.13.2-javadoc.jar
# ...
# empty_pb2.pyi
# field_mask_pb2.pyi
# json_format.pyi
# message.pyi
# message_factory.pyi
# reflection.pyi
# service.pyi
# source_context_pb2.pyi
# struct_pb2.pyi
# symbol_database.pyi
# timestamp_pb2.pyi
# type_pb2.pyi
# wrappers_pb2.pyi
# __init__.pyi
# plugin_pb2.pyi
# __init__.pyi
# containers.pyi
# decoder.pyi
# encoder.pyi
# enum_type_wrapper.pyi
# extension_dict.pyi
# message_listener.pyi
# python_message.pyi
# well_known_types.pyi
# wire_format.pyi
# __init__.pyi
# __init__.pyi
# bccache.pyi
# compiler.pyi
# constants.pyi
# debug.pyi
# defaults.pyi
# environment.pyi
# exceptions.pyi
# ext.pyi
# filters.pyi
# lexer.pyi
# loaders.pyi
# meta.pyi
# nodes.pyi
# optimizer.pyi
# parser.pyi
# runtime.pyi
# sandbox.pyi
# tests.pyi
# utils.pyi
# visitor.pyi
# _compat.pyi
# _stringdefs.pyi
# __init__.pyi
# blockparser.pyi
# blockprocessors.pyi
# core.pyi
# inlinepatterns.pyi
# pep562.pyi
# postprocessors.pyi
# preprocessors.pyi
# serializers.pyi
# treeprocessors.pyi
# util.pyi
# __init__.pyi
# __meta__.pyi
# abbr.pyi
# admonition.pyi
# attr_list.pyi
# codehilite.pyi
# def_list.pyi
# extra.pyi
# fenced_code.pyi
# footnotes.pyi
# legacy_attrs.pyi
# legacy_em.pyi
# md_in_html.pyi
# meta.pyi
# nl2br.pyi
# sane_lists.pyi
# smarty.pyi
# tables.pyi
# toc.pyi
# wikilinks.pyi
# __init__.pyi
# _compat.pyi
# _constants.pyi
# _native.pyi
# _speedups.pyi
# __init__.pyi
# compat.pyi
# const.pyi
# decoder.pyi
# errors.pyi
# extension.pyi
# reader.pyi
# __init__.pyi
# nmap.pyi
# __init__.pyi
# agent.pyi
# auth_handler.pyi
# ber.pyi
# buffered_pipe.pyi
# channel.pyi
# client.pyi
# common.pyi
# compress.pyi
# config.pyi
# dsskey.pyi
# ecdsakey.pyi
# ed25519key.pyi
# file.pyi
# hostkeys.pyi
# kex_curve25519.pyi
# kex_ecdh_nist.pyi
# kex_gex.pyi
# kex_group1.pyi
# kex_group14.pyi
# kex_group16.pyi
# kex_gss.pyi
# message.pyi
# packet.pyi
# pipe.pyi
# pkey.pyi
# primes.pyi
# proxy.pyi
# py3compat.pyi
# rsakey.pyi
# server.pyi
# sftp.pyi
# sftp_attr.pyi
# sftp_client.pyi
# sftp_file.pyi
# sftp_handle.pyi
# sftp_server.pyi
# sftp_si.pyi
# ssh_exception.pyi
# ssh_gss.pyi
# transport.pyi
# util.pyi
# win_pageant.pyi
# _version.pyi
# _winapi.pyi
# __init__.pyi
# charset.pyi
# connections.pyi
# converters.pyi
# cursors.pyi
# err.pyi
# times.pyi
# util.pyi
# __init__.pyi
# CLIENT.pyi
# COMMAND.pyi
# ER.pyi
# FIELD_TYPE.pyi
# FLAG.pyi
# SERVER_STATUS.pyi
# __init__.pyi
# attributes.pyi
# constants.pyi
# exceptions.pyi
# indexes.pyi
# models.pyi
# settings.pyi
# throttle.pyi
# types.pyi
# __init__.pyi
# base.pyi
# table.pyi
# util.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# event.pyi
# fault.pyi
# option.pyi
# view.pyi
# __init__.pyi
# fault.pyi
# query.pyi
# __init__.pyi
# client.pyi
# connection.pyi
# exceptions.pyi
# utils.pyi
# __init__.pyi
# adapters.pyi
# api.pyi
# auth.pyi
# compat.pyi
# cookies.pyi
# exceptions.pyi
# hooks.pyi
# models.pyi
# sessions.pyi
# status_codes.pyi
# structures.pyi
# utils.pyi
# __init__.pyi
# __init__.pyi
# connection.pyi
# connectionpool.pyi
# exceptions.pyi
# fields.pyi
# filepost.pyi
# poolmanager.pyi
# request.pyi
# response.pyi
# _collections.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# _implementation.pyi
# __init__.pyi
# connection.pyi
# request.pyi
# response.pyi
# retry.pyi
# ssl_.pyi
# timeout.pyi
# url.pyi
# __init__.pyi
# api.pyi
# __init__.pyi
# decoder.pyi
# encoder.pyi
# scanner.pyi
# __init__.pyi
# slugify.pyi
# special.pyi
# __init__.pyi
# __init__.pyi
# datastructures.pyi
# exceptions.pyi
# filesystem.pyi
# formparser.pyi
# http.pyi
# local.pyi
# posixemulation.pyi
# routing.pyi
# script.pyi
# security.pyi
# serving.pyi
# test.pyi
# testapp.pyi
# urls.pyi
# useragents.pyi
# utils.pyi
# wrappers.pyi
# wsgi.pyi
# _compat.pyi
# _internal.pyi
# _reloader.pyi
# __init__.pyi
# atom.pyi
# cache.pyi
# fixers.pyi
# iterio.pyi
# jsrouting.pyi
# limiter.pyi
# lint.pyi
# profiler.pyi
# securecookie.pyi
# sessions.pyi
# testtools.pyi
# wrappers.pyi
# __init__.pyi
# console.pyi
# repr.pyi
# tbtools.pyi
# __init__.pyi
# dispatcher.pyi
# http_proxy.pyi
# lint.pyi
# profiler.pyi
# proxy_fix.pyi
# shared_data.pyi
# __init__.pyi
# composer.pyi
# constructor.pyi
# cyaml.pyi
# dumper.pyi
# emitter.pyi
# error.pyi
# events.pyi
# loader.pyi
# nodes.pyi
# parser.pyi
# reader.pyi
# representer.pyi
# resolver.pyi
# scanner.pyi
# serializer.pyi
# tokens.pyi
# __init__.pyi
# contextvars.pyi
# dataclasses.pyi
# frozendict.pyi
# orjson.pyi
# base.pyi
# os.pyi
# __init__.pyi
# binary.pyi
# text.pyi
# __init__.pyi
# examples.pyi
# nodes.pyi
# __init__.pyi
# __init__.pyi
# nodes.pyi
# roles.pyi
# states.pyi
# __init__.pyi
# __init__.pyi
# api.pyi
# __init__.pyi
# algorithms.pyi
# __init__.pyi
# __init__.pyi
# pycrypto.pyi
# py_ecdsa.pyi
# __init__.pyi
# py31compat.pyi
# __init__.pyi
# generator.pyi
# parser.pyi
# utils.pyi
# __init__.pyi
# __init__.pyi
# BaseHTTPServer.pyi
# builtins.pyi
# CGIHTTPServer.pyi
# collections_abc.pyi
# configparser.pyi
# cPickle.pyi
# email_mime_base.pyi
# email_mime_multipart.pyi
# email_mime_nonmultipart.pyi
# email_mime_text.pyi
# html_entities.pyi
# html_parser.pyi
# http_client.pyi
# http_cookiejar.pyi
# http_cookies.pyi
# queue.pyi
# reprlib.pyi
# SimpleHTTPServer.pyi
# socketserver.pyi
# tkinter.pyi
# tkinter_commondialog.pyi
# tkinter_constants.pyi
# tkinter_dialog.pyi
# tkinter_filedialog.pyi
# tkinter_tkfiledialog.pyi
# tkinter_ttk.pyi
# urllib_error.pyi
# urllib_parse.pyi
# urllib_request.pyi
# urllib_response.pyi
# urllib_robotparser.pyi
# _dummy_thread.pyi
# _thread.pyi
# __init__.pyi
# error.pyi
# parse.pyi
# request.pyi
# response.pyi
# robotparser.pyi
# __init__.pyi
# ast27.pyi
# ast3.pyi
# conversions.pyi
# __init__.pyi
# adjustments.pyi
# buffers.pyi
# channel.pyi
# compat.pyi
# parser.pyi
# proxy_headers.pyi
# receiver.pyi
# rfc7230.pyi
# runner.pyi
# server.pyi
# task.pyi
# trigger.pyi
# utilities.pyi
# wasyncore.pyi
# __init__.pyi
# python.h
# py_custom_pyeval_settrace.hpp
# py_custom_pyeval_settrace_310.hpp
# py_custom_pyeval_settrace_common.hpp
# py_settrace.hpp
# py_utils.hpp
# py_version.hpp
# ref_utils.hpp
# .gitignore
# attach.cpp
# compile_linux.sh
# compile_mac.sh
# compile_manylinux.cmd
# lldb_prepare.py
# breakpoint.py
# compat.py
# crash.py
# debug.py
# disasm.py
# event.py
# interactive.py
# module.py
# process.py
# registry.py
# search.py
# sql.py
# system.py
# textio.py
# thread.py
# util.py
# window.py
# __init__.py
# do_example.py
# do_exchain.py
# do_exploitable.py
# do_symfix.py
# README
# __init__.py
# advapi32.py
# context_amd64.py
# context_i386.py
# dbghelp.py
# defines.py
# gdi32.py
# kernel32.py
# ntdll.py
# peb_teb.py
# psapi.py
# shell32.py
# shlwapi.py
# user32.py
# version.py
# wtsapi32.py
# __init__.py
# attach.cpp
# attach.h
# compile_windows.bat
# inject_dll.cpp
# py_win_helpers.hpp
# run_code_in_memory.hpp
# run_code_on_dllmain.cpp
# stdafx.cpp
# stdafx.h
# targetver.h
# README.md
# __init__.py
# pydevd_helpers.py
# pydevd_plugins_django_form_str.py
# pydevd_plugin_numpy_types.py
# __init__.py
# debugProtocol.json
# debugProtocolCustom.json
# pydevd_base_schema.py
# pydevd_schema.py
# pydevd_schema_log.py
# __init__.py
# __main__pydevd_gen_debug_adapter_protocol.py
# pydevd_fix_code.py
# README.txt
# __init__.py
# bytecode.py
# cfg.py
# concrete.py
# flags.py
# instr.py
# peephole_opt.py
# __init__.py
# test_bytecode.py
# test_cfg.py
# test_code.py
# test_concrete.py
# test_flags.py
# test_instr.py
# test_misc.py
# test_peephole_opt.py
# util_annotation.py
# __init__.py
# scandir_vendored.py
# __init__.py
# .eslintignore
# .vsixmanifest
# cgmanifest.json
# CHANGELOG.md
# icon.png
# LICENSE.txt
# package.json
# package.nls.cs.json
# package.nls.de.json
# package.nls.es.json
# package.nls.fr.json
# package.nls.it.json
# package.nls.ja.json
# package.nls.json
# package.nls.ko.json
# package.nls.pl.json
# package.nls.pt-BR.json
# package.nls.qps-ploc.json
# package.nls.ru.json
# package.nls.tr.json
# package.nls.zh-Hans.json
# package.nls.zh-Hant.json
# README.md
# requirements.txt
# SECURITY.md
# SUPPORT.md
# telemetry.json
# ThirdPartyNotices-Repository.txt
# ThirdPartyNotices.txt
# extension.browser.js
# extension.browser.js.LICENSE.txt
# addIcon.PNG
# codeIcon.PNG
# dataViewerIcon.PNG
# exportIcon.PNG
# markdownIcon.PNG
# playIcon.PNG
# plotViewerIcon.PNG
# variableExplorerIcon.PNG
# pip-requirements.json
# 394.js
# 505.js
# 698.js
# 698.js.LICENSE.txt
# extension.js
# extension.js.LICENSE.txt
# extension.js.map.disabled
# nls.bundle.cs.json
# nls.bundle.de.json
# nls.bundle.es.json
# nls.bundle.fr.json
# nls.bundle.it.json
# nls.bundle.ja.json
# nls.bundle.ko.json
# nls.bundle.pl.json
# nls.bundle.pt-BR.json
# nls.bundle.qps-ploc.json
# nls.bundle.ru.json
# nls.bundle.tr.json
# nls.bundle.zh-Hans.json
# nls.bundle.zh-Hant.json
# nls.metadata.header.json
# nls.metadata.json
# package.json
# diff-match-patch.js
# node-stream-zip.js
# node-stream-zip.js.LICENSE.txt
# request-progress.js
# request.js
# request.js.LICENSE.txt
# source-map-support.js
# sudo-prompt.js
# xml2js.js
# xml2js.js.LICENSE.txt
# Ll.js
# Lm.js
# Lo.js
# Lt.js
# Lu.js
# Mc.js
# Mn.js
# Nd.js
# Nl.js
# Pc.js
# macPythonInterpreter.nls.metadata.json
# powerShellActivation.nls.metadata.json
# pythonInterpreter.nls.metadata.json
# localize.nls.metadata.json
# service.nls.metadata.json
# moduleInstaller.nls.metadata.json
# productInstaller.nls.metadata.json
# fileDownloader.nls.metadata.json
# localize.nls.metadata.json
# banner.nls.metadata.json
# factory.nls.metadata.json
# provider.nls.metadata.json
# pyramidLaunch.nls.metadata.json
# childProcessAttachService.nls.metadata.json
# blackFormatter.nls.metadata.json
# pythonPathUpdaterService.nls.metadata.json
# setInterpreter.nls.metadata.json
# index.nls.metadata.json
# watcher.nls.metadata.json
# linterCommands.nls.metadata.json
# standard.nls.metadata.json
# importSortProvider.nls.metadata.json
# tensorBoardSession.nls.metadata.json
# tensorBoardSessionProvider.nls.metadata.json
# helper.nls.metadata.json
# debugLauncher.nls.metadata.json
# .env
# create_conda.py
# create_venv.py
# get-pip.py
# get_output_via_markers.py
# install_debugpy.py
# interpreterInfo.py
# linter.py
# normalizeSelection.py
# Notebooks intro.ipynb
# printEnvVariables.py
# printEnvVariablesToFile.py
# pyproject.toml
# run-jedi-language-server.py
# shell_exec.py
# sortImports.py
# tensorboard_launcher.py
# testlauncher.py
# visualstudio_py_testlauncher.py
# settings.json
# README.md
# typing_extensions.py
# zipp.py
# jedi-language-server
# py.typed
# rst.py
# __init__.py
# py.typed
# _collections.py
# _compat.py
# _functools.py
# _itertools.py
# __init__.py
# cache.py
# common.py
# debug.py
# file_io.py
# parser_utils.py
# settings.py
# utils.py
# _compatibility.py
# __init__.py
# __main__.py
# classes.py
# completion.py
# completion_cache.py
# environment.py
# errors.py
# exceptions.py
# file_name.py
# helpers.py
# interpreter.py
# keywords.py
# project.py
# replstartup.py
# strings.py
# __init__.py
# extract.py
# __init__.py
# analysis.py
# arguments.py
# base_value.py
# cache.py
# context.py
# docstrings.py
# docstring_utils.py
# dynamic_params.py
# filters.py
# finder.py
# flow_analysis.py
# helpers.py
# imports.py
# lazy_value.py
# names.py
# param.py
# parser_cache.py
# recursion.py
# references.py
# signature.py
# star_args.py
# syntax_tree.py
# sys_path.py
# utils.py
# __init__.py
# access.py
# getattr_static.py
# mixed.py
# value.py
# __init__.py
# functions.py
# __init__.py
# __main__.py
# annotation.py
# base.py
# conversion.py
# generics.py
# stub_value.py
# typeshed.py
# type_var.py
# typing.py
# utils.py
# __init__.py
# decorator.py
# dynamic_arrays.py
# function.py
# instance.py
# iterable.py
# klass.py
# module.py
# namespace.py
# __init__.py
# django.py
# flask.py
# pytest.py
# registry.py
# stdlib.py
# __init__.py
# LICENSE.txt
# shortcuts.pyi
# __init__.pyi
# config.pyi
# registry.pyi
# __init__.pyi
# global_settings.pyi
# __init__.pyi
# __init__.pyi
# i18n.pyi
# static.pyi
# __init__.pyi
# __init__.pyi
# actions.pyi
# apps.pyi
# checks.pyi
# decorators.pyi
# filters.pyi
# forms.pyi
# helpers.pyi
# models.pyi
# options.pyi
# sites.pyi
# tests.pyi
# utils.pyi
# widgets.pyi
# __init__.pyi
# admin_list.pyi
# admin_modify.pyi
# admin_static.pyi
# admin_urls.pyi
# base.pyi
# log.pyi
# __init__.pyi
# autocomplete.pyi
# decorators.pyi
# main.pyi
# __init__.pyi
# middleware.pyi
# urls.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# backends.pyi
# base_user.pyi
# checks.pyi
# context_processors.pyi
# decorators.pyi
# forms.pyi
# hashers.pyi
# middleware.pyi
# mixins.pyi
# models.pyi
# password_validation.pyi
# signals.pyi
# tokens.pyi
# urls.pyi
# validators.pyi
# views.pyi
# __init__.pyi
# modwsgi.pyi
# __init__.pyi
# __init__.pyi
# changepassword.pyi
# createsuperuser.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# checks.pyi
# fields.pyi
# forms.pyi
# models.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# remove_stale_contenttypes.pyi
# __init__.pyi
# forms.pyi
# middleware.pyi
# models.pyi
# sitemaps.pyi
# urls.pyi
# views.pyi
# __init__.pyi
# flatpages.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# fields.pyi
# __init__.pyi
# __init__.pyi
# humanize.pyi
# __init__.pyi
# api.pyi
# constants.pyi
# context_processors.pyi
# middleware.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# base.pyi
# cookie.pyi
# fallback.pyi
# session.pyi
# __init__.pyi
# constraints.pyi
# functions.pyi
# indexes.pyi
# lookups.pyi
# operations.pyi
# search.pyi
# signals.pyi
# validators.pyi
# __init__.pyi
# general.pyi
# mixins.pyi
# statistics.pyi
# __init__.pyi
# array.pyi
# citext.pyi
# hstore.pyi
# jsonb.pyi
# mixins.pyi
# ranges.pyi
# __init__.pyi
# middleware.pyi
# models.pyi
# __init__.pyi
# base_session.pyi
# exceptions.pyi
# middleware.pyi
# models.pyi
# serializers.pyi
# __init__.pyi
# base.pyi
# cache.pyi
# cached_db.pyi
# db.pyi
# file.pyi
# signed_cookies.pyi
# __init__.pyi
# __init__.pyi
# clearsessions.pyi
# __init__.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# ping_google.pyi
# __init__.pyi
# apps.pyi
# management.pyi
# managers.pyi
# middleware.pyi
# models.pyi
# requests.pyi
# shortcuts.pyi
# __init__.pyi
# apps.pyi
# checks.pyi
# finders.pyi
# handlers.pyi
# storage.pyi
# testing.pyi
# urls.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# collectstatic.pyi
# findstatic.pyi
# runserver.pyi
# __init__.pyi
# staticfiles.pyi
# __init__.pyi
# views.pyi
# __init__.pyi
# exceptions.pyi
# paginator.pyi
# signals.pyi
# signing.pyi
# validators.pyi
# wsgi.pyi
# __init__.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# db.pyi
# dummy.pyi
# filebased.pyi
# locmem.pyi
# memcached.pyi
# __init__.pyi
# caches.pyi
# database.pyi
# messages.pyi
# model_checks.pyi
# registry.pyi
# templates.pyi
# translation.pyi
# urls.pyi
# __init__.pyi
# base.pyi
# csrf.pyi
# sessions.pyi
# __init__.pyi
# base.pyi
# images.pyi
# locks.pyi
# move.pyi
# storage.pyi
# temp.pyi
# uploadedfile.pyi
# uploadhandler.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# exception.pyi
# wsgi.pyi
# __init__.pyi
# message.pyi
# utils.pyi
# __init__.pyi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 import os
# ----> 2 for folders, subfolders, files in os.walk(os.getcwd()):
#       3     for file in files:
#       4         print(file)
#
# File ~\anaconda3\lib\os.py:418, in _walk(top, topdown, onerror, followlinks)
#     413         # Issue #23605: os.path.islink() is used instead of caching
#     414         # entry.is_symlink() result during the loop on os.scandir() because
#     415         # the caller can replace the directory entry during the "yield"
#     416         # above.
#     417         if followlinks or not islink(new_path):
# --> 418             yield from _walk(new_path, topdown, onerror, followlinks)
#     419 else:
#     420     # Recurse into sub-directories
#     421     for new_path in walk_dirs:
#
# File ~\anaconda3\lib\os.py:418, in _walk(top, topdown, onerror, followlinks)
#     413         # Issue #23605: os.path.islink() is used instead of caching
#     414         # entry.is_symlink() result during the loop on os.scandir() because
#     415         # the caller can replace the directory entry during the "yield"
#     416         # above.
#     417         if followlinks or not islink(new_path):
# --> 418             yield from _walk(new_path, topdown, onerror, followlinks)
#     419 else:
#     420     # Recurse into sub-directories
#     421     for new_path in walk_dirs:
#
#     [... skipping similar frames: _walk at line 418 (10 times)]
#
# File ~\anaconda3\lib\os.py:418, in _walk(top, topdown, onerror, followlinks)
#     413         # Issue #23605: os.path.islink() is used instead of caching
#     414         # entry.is_symlink() result during the loop on os.scandir() because
#     415         # the caller can replace the directory entry during the "yield"
#     416         # above.
#     417         if followlinks or not islink(new_path):
# --> 418             yield from _walk(new_path, topdown, onerror, followlinks)
#     419 else:
#     420     # Recurse into sub-directories
#     421     for new_path in walk_dirs:
#
# File ~\anaconda3\lib\os.py:357, in _walk(top, topdown, onerror, followlinks)
#     349 # We may not have read permission for top, in which case we can't
#     350 # get a list of the files the directory contains.  os.walk
#     351 # always suppressed the exception then, rather than blow up for a
#     352 # minor reason when (say) a thousand readable directories are still
#     353 # left to visit.  That logic is copied here.
#     354 try:
#     355     # Note that scandir is global in this module due
#     356     # to earlier import-*.
# --> 357     scandir_it = scandir(top)
#     358 except OSError as error:
#     359     if onerror is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os 
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.angular-config.json',
#  '.astropy',
#  '.bash_history',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.continuum',
#  '.cufflinks',
#  '.dotnet',
#  '.eclipse',
#  '.emulator_console_auth_token',
#  '.frostwire5',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.librarymanager',
#  '.m2',
#  '.matplotlib',
#  '.nbi',
#  '.node_repl_history',
#  '.nuget',
#  '.opera',
#  '.p2',
#  '.ssh',
#  '.swt',
#  '.tooling',
#  '.vscode',
#  '18.1.1 data visualization Introduction.ipynb',
#  '3D Objects',
#  'AgentLogingReport.csv',
#  'AgentPerformance.csv',
#  'anaconda3',
#  'AndroidStudioProjects',
#  'AppData',
#  'Apple',
#  'Application Data',
#  'Ashu.txt',
#  'Assignment 1.ipynb',
#  'Assignment12.ipynb',
#  'Assignment13.ipynb',
#  'Assignment14.ipynb',
#  'Assignment15.ipynb',
#  'Assignment16.ipynb',
#  'Assignment17.ipynb',
#  'Assignment18.ipynb',
#  'Assignment19.ipynb',
#  'Assignment20.ipynb',
#  'Assignment21.ipynb',
#  'Attribute DataSet.xlsx',
#  'books.csv',
#  'books.db',
#  'Contacts',
#  'Cookies',
#  'd4ac4633ebd6440fa397b84f1bc94a3c.7z',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Dress Sales.xlsx',
#  'eclipse',
#  'eclipse-workspace',
#  'EFCodeFirstExample.BloggingContext.mdf',
#  'EFCodeFirstExample.BloggingContext_log.ldf',
#  'Favorites',
#  'IBA_IOAPDATA',
#  'inittk.ini',
#  'inst.ini',
#  'Intel',
#  'IntelGraphicsProfiles',
#  'Iterator Iterable.ipynb',
#  'Links',
#  'Local Settings',
#  'Logging Debuging.ipynb',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'Nox_share',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{1ef16db1-f2b8-11ea-a2cd-c485a81d765f}.TM.blf',
#  'NTUSER.DAT{1ef16db1-f2b8-11ea-a2cd-c485a81d765f}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{1ef16db1-f2b8-11ea-a2cd-c485a81d765f}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'ntuser.tmp',
#  'nuuid.ini',
#  'OneDrive',
#  'opera autoupdate',
#  'Pictures',
#  'Postman',
#  'PrintHood',
#  'PycharmProjects',
#  'Recent',
#  'Saved Games',
#  'seaborn-data',
#  'Searches',
#  'SendTo',
#  'source',
#  'Start Menu',
#  'Templates',
#  'test.json',
#  'test.txt',
#  'Test1.txt',
#  'Test2.txt',
#  'test234.csv',
#  'Text2.txt',
#  'today.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled14.ipynb',
#  'Untitled15.ipynb',
#  'Untitled16.ipynb',
#  'Untitled17.ipynb',
#  'Untitled18.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'Videos',
#  'zoo.py',
#  '__pycache__']

# %% [markdown]
# 6. Use multiprocessing to create three separate processes. Make each one wait a random number of
# seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

# %% [markdown]
# 7. Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('12/01/1994','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 1994-01-12 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# 8. What day of the week was your day of birth?

# %%
from datetime import datetime
my_dob = datetime(1994,1,12)
my_dob.strftime("%A")
# Out:
# 'Wednesday'

# %% [markdown]
# 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("12/01/1994",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1966, 8, 27, 0, 0)
